# %% [markdown]
# # Circuit
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## $ V_0 =  5 $ $ R_1 = 1 $ $ R_2 = 3 $ $ R_3 = 5 $ $ A = 2 $

# %% [markdown]
# ## KVL
#
# ### $ x $ is current counter clockwise
#
# ### $ -V_0 + R_1 I_0  + R_2 I_0 - R_3 I_0 = 0 $

# %% [markdown]
# ### $ (u - V_0) / R_1 = x $ so $ u = V_0  + R_1 x $
